# %% [markdown]
# # Linked Lists
#
# In today's class, were going to introduce the two varieties of linked lists:
# 1. Singly Linked Lists (uni-directional)
# 2. Doubly Linked Lists (bi-directional)

# %%
# how python does it

help([])
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
mylist =  []
#printing an empty list
print(mylist)

mylist.append(0)
#printing a list with exactly one element:
print(mylist)

mylist.append(1)
#printing list with more than one element:
print(mylist)
# Out:
# []
# [0]
# [0, 1]

# %%
# from scratch implementation of Singly Linked List



class SinglyLinkedList:
    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None


    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node




        # create new_node with incoming value
        # if there is no head:
        #     make it so that new node is head node 
        #     also make it so that my new node is the tail node
        # otherwise
        #     if the index i recieved is 0:
        #          replace the head reference to point to my new node
        #     otherwise:
        #           initialize a varible called current which starts by pointing at the head node
        #           initialize a varible called previous which starts by pointing to none
        #           loop while these two conditions are not met ->
        #                  condition 1: there must be a next node to loop into
        #                  condition 2: I have not yet found the target index
        #           these are instructions that happen everytime i loop:
        #                  1. I update previous to point to the same thing current is pointing to
        #                  2. I update current to point to the next node in my list
        #                  3. I update count suchh that count is now equal to count plus 1
        #     when I exit the loop one of two conditions can be met:
        #           if count is equal to index:         (this means i found target index)
        #                  update the previous node's next reference to point to the new node
        #                  update the node's next reference to point to current
        #           otherwise:                          (this means I exhausted thhe list and never found the index)
        #                  execute the append operation
    def insert(self, index, value)



    


    
    def remove(self, value)
        current = self.head
        previous = None
        while current:
            if current.data == value:
                






    
    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" %  repr(current.data)
            while current.next:
                current = current.next
                out += ", %s" % repr(current.data)
        out += "]"
        return out

# %%
sll = SinglyLinkedList()

# when the list is empty:
print(sll)

# when the list contains exactly one element
sll.append(0)
print(sll)

# when the list contains more than one element
sll.append(1)
print(sll)
# Out:
# []
# [0]
# [0, 1]

# %%
# with python lists
newlist  = []

# inserting at index 1000 on an empty list
newlist.insert(1000, "A")

print(newlist)

# replacing the head node
newlist.insert(0, "Z")
print(newlist)
# when the provided index is exactly equal to 0, we are replacing the head node withh insert

# inserting anywhere between head and tail
newlist.insert(1, 1)
print(newlist)
# Out:
# ['A']
# ['Z', 'A']
# ['Z', 1, 'A']
